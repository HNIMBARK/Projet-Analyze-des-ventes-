# %%
import pandas as pd

# %%
df = pd.read_csv('Sales_data.csv', encoding= 'unicode_escape')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#              State      Zone       Occupation Product_Category  Orders  \
# 0      Maharashtra   Western       Healthcare             Auto       1
# 1  AndhraÂ Pradesh  Southern             Govt             Auto       3
# 2    Uttar Pradesh   Central       Automobile             Auto       3
# 3        Karnataka  Southern     Construction             Auto       2
# 4          Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (103, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           103 non-null    int64
#  1   Cust_name         103 non-null    object
#  2   Product_ID        103 non-null    object
#  3   Gender            103 non-null    object
#  4   Age Group         103 non-null    object
#  5   Age               103 non-null    int64
#  6   Marital_Status    103 non-null    int64
#  7   State             103 non-null    object
#  8   Zone              103 non-null    object
#  9   Occupation        103 non-null    object
#  10  Product_Category  103 non-null    object
#  11  Orders            103 non-null    int64
#  12  Amount            100 non-null    float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 12.2+ KB

# %%
#supprimer les colones contenant des valeurs nulls
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              3
# dtype: int64

# %%
# supprimer les valeurs nulls
df.dropna(inplace=True)

# %%
#changer le type de data (int au lieu de float)
df['Amount'] = df['Amount'].astype('int')

# %%
df.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns= {'Marital_Status':'Status'})
# 0 si celibataire et 1 si marié
# Out:
#      User_ID   Cust_name Product_ID Gender Age Group  Age  Status  \
# 0    1002903   Sanskriti  P00125942      F     26-35   28       0
# 1    1000732      Kartik  P00110942      F     26-35   35       1
# 2    1001990       Bindu  P00118542      F     26-35   35       1
# 3    1001425      Sudevi  P00237842      M      0-17   16       0
# 4    1000588        Joni  P00057942      M     26-35   28       1
# ..       ...         ...        ...    ...       ...  ...     ...
# 98   1001891        Akin  P00192542      F     46-50   46       0
# 99   1001019        Neil  P00259142      F     36-45   43       1
# 100  1002306       Lisha  P00084242      M     18-25   21       1
# 101  1001179       Amlan  P00208742      M     51-55   54       0
# 102  1004957  Inderpreet  P00163442      F     26-35   34       1
#
#                State      Zone       Occupation  Product_Category  Orders  \
# 0        Maharashtra   Western       Healthcare              Auto       1
# ...

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#               Age      Orders       Amount
# count  100.000000  100.000000    100.00000
# mean    34.800000    2.390000  22255.36000
# std     12.011779    1.118215   1202.11274
# min     16.000000    1.000000  20914.00000
# 25%     26.000000    1.000000  21002.00000
# 50%     34.000000    2.000000  21540.00000
# 75%     40.500000    3.000000  23438.25000
# max     83.000000    4.000000  23952.00000

# %%
# plotting a bar chart for Gender and it's count
import seaborn as sns
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)
